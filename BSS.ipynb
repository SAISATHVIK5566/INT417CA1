# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/drive/MyDrive/INT247/ElectionData.csv')

# %%
df.head()
# Out:
#    TimeElapsed                 time        territoryName  totalMandates  \
# 0            0  2019-10-06 20:10:02  Território Nacional              0
# 1            0  2019-10-06 20:10:02  Território Nacional              0
# 2            0  2019-10-06 20:10:02  Território Nacional              0
# 3            0  2019-10-06 20:10:02  Território Nacional              0
# 4            0  2019-10-06 20:10:02  Território Nacional              0
#
#    availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0                226         3092                 1081        9652
# 1                226         3092                 1081        9652
# 2                226         3092                 1081        9652
# 3                226         3092                 1081        9652
# 4                226         3092                 1081        9652
#
#    blankVotesPercentage  nullVotes  ...  pre.votersPercentage  \
# 0                   2.5       8874  ...                 52.66
# ...

# %%
df.tail()
# Out:
#        TimeElapsed                 time territoryName  totalMandates  \
# 21638          265  2019-10-07 00:35:01         Viseu              8
# 21639          265  2019-10-07 00:35:01         Viseu              8
# 21640          265  2019-10-07 00:35:01         Viseu              8
# 21641          265  2019-10-07 00:35:01         Viseu              8
# 21642          265  2019-10-07 00:35:01         Viseu              8
#
#        availableMandates  numParishes  numParishesApproved  blankVotes  \
# 21638                  0          277                  277        4995
# 21639                  0          277                  277        4995
# 21640                  0          277                  277        4995
# 21641                  0          277                  277        4995
# 21642                  0          277                  277        4995
#
#        blankVotesPercentage  nullVotes  ...  pre.votersPercentage  \
# ...

# %%
df.shape
# Out:
# (21643, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21643 entries, 0 to 21642
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TimeElapsed               21643 non-null  int64
#  1   time                      21643 non-null  object
#  2   territoryName             21643 non-null  object
#  3   totalMandates             21643 non-null  int64
#  4   availableMandates         21643 non-null  int64
#  5   numParishes               21643 non-null  int64
#  6   numParishesApproved       21643 non-null  int64
#  7   blankVotes                21643 non-null  int64
#  8   blankVotesPercentage      21643 non-null  float64
#  9   nullVotes                 21643 non-null  int64
#  10  nullVotesPercentage       21643 non-null  float64
#  11  votersPercentage          21643 non-null  float64
#  12  subscribedVoters          21643 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# TimeElapsed                 0
# time                        0
# territoryName               0
# totalMandates               0
# availableMandates           0
# numParishes                 0
# numParishesApproved         0
# blankVotes                  0
# blankVotesPercentage        0
# nullVotes                   0
# nullVotesPercentage         0
# votersPercentage            0
# subscribedVoters            0
# totalVoters                 0
# pre.blankVotes              0
# pre.blankVotesPercentage    0
# pre.nullVotes               0
# pre.nullVotesPercentage     0
# pre.votersPercentage        0
# pre.subscribedVoters        0
# pre.totalVoters             0
# Party                       0
# Mandates                    0
# Percentage                  0
# validVotesPercentage        0
# Votes                       0
# Hondt                       0
# FinalMandates               0
# dtype: int64

# %%
df.dtypes
# Out:
# TimeElapsed                   int64
# time                         object
# territoryName                object
# totalMandates                 int64
# availableMandates             int64
# numParishes                   int64
# numParishesApproved           int64
# blankVotes                    int64
# blankVotesPercentage        float64
# nullVotes                     int64
# nullVotesPercentage         float64
# votersPercentage            float64
# subscribedVoters              int64
# totalVoters                   int64
# pre.blankVotes                int64
# pre.blankVotesPercentage    float64
# pre.nullVotes                 int64
# pre.nullVotesPercentage     float64
# pre.votersPercentage        float64
# pre.subscribedVoters          int64
# pre.totalVoters               int64
# Party                        object
# Mandates                      int64
# Percentage                  float64
# validVotesPercentage        float64
# Votes                         int64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['TimeElapsed'].hist()

# %%
df['Party'].hist()

# %%
df['nullVotesPercentage'].hist()

# %%
df['territoryName'].hist()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),cmap = 'coolwarm',linewidth = 1,annot= True, annot_kws={"size": 9})
plt.title('Variable Correlation')
# Out:
# Text(0.5, 1.0, 'Variable Correlation')

# %%
df.drop(['totalMandates','numParishesApproved','blankVotes','nullVotes','subscribedVoters','totalVoters','pre.blankVotes','pre.nullVotes','pre.subscribedVoters','pre.totalVoters','Percentage','Mandates','pre.blankVotesPercentage','pre.votersPercentage'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    TimeElapsed                 time        territoryName  availableMandates  \
# 0            0  2019-10-06 20:10:02  Território Nacional                226
# 1            0  2019-10-06 20:10:02  Território Nacional                226
# 2            0  2019-10-06 20:10:02  Território Nacional                226
# 3            0  2019-10-06 20:10:02  Território Nacional                226
# 4            0  2019-10-06 20:10:02  Território Nacional                226
#
#    numParishes  blankVotesPercentage  nullVotesPercentage  votersPercentage  \
# 0         3092                   2.5                  2.3             51.36
# 1         3092                   2.5                  2.3             51.36
# 2         3092                   2.5                  2.3             51.36
# 3         3092                   2.5                  2.3             51.36
# 4         3092                   2.5                  2.3             51.36
#
# ...

# %%
df.shape
# Out:
# (21643, 14)

# %%
df.territoryName.value_counts()
# Out:
# Território Nacional    1134
# Braga                  1134
# Porto                  1134
# Leiria                 1134
# Madeira                1080
# Coimbra                1080
# Aveiro                 1080
# Lisboa                 1080
# Viseu                  1080
# Viana do Castelo       1080
# Setúbal                1080
# Santarém               1026
# Évora                  1026
# Faro                   1026
# Guarda                 1026
# Bragança                972
# Castelo Branco          972
# Beja                    918
# Portalegre              918
# Vila Real               864
# Açores                  799
# Name: territoryName, dtype: int64

# %%
df.Party.value_counts()
# Out:
# PS           1127
# PCTP/MRPP    1127
# PNR          1127
# PDR          1127
# IL           1127
# PPD/PSD      1127
# A            1127
# L            1127
# CH           1127
# PAN          1127
# PCP-PEV      1127
# CDS-PP       1127
# B.E.         1127
# PPM          1073
# R.I.R.       1026
# MPT          1019
# PTP          1019
# NC            972
# PURP          972
# JPP           486
# MAS           425
# Name: Party, dtype: int64

# %%
df.drop(['time','territoryName','Party'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    TimeElapsed  availableMandates  numParishes  blankVotesPercentage  \
# 0            0                226         3092                   2.5
# 1            0                226         3092                   2.5
# 2            0                226         3092                   2.5
# 3            0                226         3092                   2.5
# 4            0                226         3092                   2.5
#
#    nullVotesPercentage  votersPercentage  pre.nullVotesPercentage  \
# 0                  2.3             51.36                     1.91
# 1                  2.3             51.36                     1.91
# 2                  2.3             51.36                     1.91
# 3                  2.3             51.36                     1.91
# 4                  2.3             51.36                     1.91
#
#    validVotesPercentage   Votes  Hondt  FinalMandates
# 0                 40.22  147993     94            106
# ...

# %%
df.describe()
# Out:
#         TimeElapsed  availableMandates   numParishes  blankVotesPercentage  \
# count  21643.000000       21643.000000  21643.000000          21643.000000
# mean     133.146052          11.499284    309.956013              2.621629
# std       77.651193          31.738783    659.055911              0.795289
# min        0.000000           0.000000     54.000000              0.530000
# 25%       65.000000           0.000000     75.000000              2.230000
# 50%      135.000000           3.000000    147.000000              2.640000
# 75%      200.000000           9.000000    242.000000              2.980000
# max      265.000000         226.000000   3092.000000              5.460000
#
#        nullVotesPercentage  votersPercentage  pre.nullVotesPercentage  \
# count         21643.000000      21643.000000             21643.000000
# mean              1.961471         51.983722                 1.777442
# std               0.375250          4.854380                 0.388798
# ...

# %%
x=df.drop(['FinalMandates'],axis=1)  
y=df['FinalMandates']     
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train.describe()
# Out:
#         TimeElapsed  availableMandates   numParishes  blankVotesPercentage  \
# count  15150.000000       15150.000000  15150.000000          15150.000000
# mean     133.196700          11.483696    306.481716              2.620642
# std       77.861367          32.072420    652.190121              0.794711
# min        0.000000           0.000000     54.000000              0.530000
# 25%       65.000000           0.000000     75.000000              2.230000
# 50%      135.000000           3.000000    147.000000              2.640000
# 75%      200.000000           9.000000    242.000000              2.980000
# max      265.000000         226.000000   3092.000000              5.460000
#
#        nullVotesPercentage  votersPercentage  pre.nullVotesPercentage  \
# count         15150.000000      15150.000000             15150.000000
# mean              1.963353         51.982158                 1.778868
# std               0.375565          4.850437                 0.390218
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x_train_sc=sc.fit_transform(x_train)

# %%
pd.DataFrame(x_train_sc).describe()
# Out:
#                   0             1             2             3             4  \
# count  1.515000e+04  1.515000e+04  1.515000e+04  1.515000e+04  1.515000e+04
# mean   1.111689e-16  9.267981e-17  5.908640e-17  3.453950e-16 -1.152433e-16
# std    1.000033e+00  1.000033e+00  1.000033e+00  1.000033e+00  1.000033e+00
# min   -1.710747e+00 -3.580670e-01 -3.871418e-01 -2.630781e+00 -1.659828e+00
# 25%   -8.759023e-01 -3.580670e-01 -3.549415e-01 -4.915687e-01 -6.479863e-01
# 50%    2.316116e-02 -2.645256e-01 -2.445406e-01  2.435903e-02 -2.485752e-01
# 75%    8.580058e-01 -7.744281e-02 -9.887277e-02  4.522016e-01  7.100114e-01
# max    1.692850e+00  6.688718e+00  4.271163e+00  3.572935e+00  3.692281e+00
#
#                   5             6             7             8             9
# count  1.515000e+04  1.515000e+04  1.515000e+04  1.515000e+04  1.515000e+04
# mean   4.015490e-16  1.197429e-16 -1.362680e-17  2.334400e-17  5.456398e-16
# ...

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train_sc,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
regressor.score(x_train_sc,y_train)
# Out:
# 0.9908329684450342

# %%
regressor.score(x_test,y_test)
# Out:
# -42512628.607965626

# %%
from sklearn import metrics
print('MAE:',metrics.mean_absolute_error(y_test,y_pred))
print('MSE:',metrics.mean_squared_error(y_test,y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print('R^2 =',metrics.explained_variance_score(y_test,y_pred))
# Out:
# MAE: 7874.337069846151
# MSE: 2388756574.794271
# RMSE: 48874.907414687455
# R^2 = -41413422.305383645

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train_sc,y_train)
# Out:
# LogisticRegression()

# %%
train_pred_lr=lr.predict(x_train_sc)
test_pred_lr=lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print("Training Accuracy :",accuracy_score(y_train,train_pred_lr))
print("Testing Accuracy :",accuracy_score(y_test,test_pred_lr))
# Out:
# Training Accuracy : 0.9523432343234324
# Testing Accuracy : 0.011242876944401663

# %%
y_pred_lr=lr.predict(x_test)

# %%
from sklearn import metrics
print('MAE:',metrics.mean_absolute_error(y_test,y_pred_lr))
print('MSE:',metrics.mean_squared_error(y_test,y_pred_lr))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,y_pred_lr)))
print('R^2 =',metrics.explained_variance_score(y_test,y_pred_lr))
# Out:
# MAE: 24.999383951948253
# MSE: 1295.190666872016
# RMSE: 35.98875750664388
# R^2 = -11.07923800691669

# %%
from sklearn. svm import SVC

# %%
svc=SVC()

# %%
svc.fit(x_train_sc,y_train)
# Out:
# SVC()

# %%
train_pred_svc=svc.predict(x_train_sc)
test_pred_svc=svc.predict(x_test)

# %%
y_pred_svm=svc.predict(x_test)

# %%
print("Training accuracy :",accuracy_score(train_pred_svc,y_train))
print("Testing accuracy:",accuracy_score(test_pred_svc,y_test))
# Out:
# Training accuracy : 0.9737293729372938
# Testing accuracy: 0.8256584013553057

# %%
from sklearn import metrics
print('MAE:',metrics.mean_absolute_error(y_test,y_pred_svm))
print('MSE:',metrics.mean_squared_error(y_test,y_pred_svm))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,y_pred_svm)))
print('R^2 =',metrics.explained_variance_score(y_test,y_pred_svm))
# Out:
# MAE: 1.219775142461112
# MSE: 57.67719082088403
# RMSE: 7.594550073630697
# R^2 = 0.0

# %%
from sklearn.ensemble import VotingClassifier

# %%
vc=VotingClassifier(estimators=[('logistic',lr),('support',svc)],voting='hard',weights=[1,1])

# %%
# Soft voting - work on probability values
vc.fit(x_train_sc,y_train)
# Out:
# VotingClassifier(estimators=[('logistic', LogisticRegression()),
#                              ('support', SVC())],
#                  weights=[1, 1])

# %%
train_pred_vc=vc.predict(x_train_sc)
test_pred_vc=vc.predict(x_test)

# %%
print("Training accuracy :",accuracy_score(train_pred_vc,y_train))
print("Testing accuracy:",accuracy_score(test_pred_vc,y_test))
# Out:
# Training accuracy : 0.9552475247524752
# Testing accuracy: 0.8256584013553057

# %%
y_pred_vc=vc.predict(x_test)

# %%
from sklearn import metrics
print('MAE:',metrics.mean_absolute_error(y_test,y_pred_vc))
print('MSE:',metrics.mean_squared_error(y_test,y_pred_vc))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,y_pred_vc)))
print('R^2 =',metrics.explained_variance_score(y_test,y_pred_vc))
# Out:
# MAE: 1.219775142461112
# MSE: 57.67719082088403
# RMSE: 7.594550073630697
# R^2 = 0.0

# %%
2
